# %%
import sys
import os
import pandas as pd


# Use the current working directory instead of __file__
current_working_directory = os.getcwd()
sys.path.insert(0, current_working_directory)

# %%
from jgtpy import mfihelper as mfih

# %%
t="D1"
ctxfn="/b/Dropbox/_jgongery/hfsp_basjupyterlab2406private/data/jgtml_mx_pto_240702_CONT02_mfi_str_df_SPX500_D1.csv"
ctxfn="/var/lib/jgt/full/data/cds/SPX500_D1.csv"

# %%
df=pd.read_csv(ctxfn, index_col=0, parse_dates=True)

# %%
df
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 1982-04-21 22:00:00   115.48   116.58   114.44    115.72   115.48   116.58
# 1982-04-22 22:00:00   115.72   117.25   115.72    117.19   115.72   117.25
# 1982-04-23 22:00:00   118.02   118.64   117.19    118.64   118.02   118.64
# 1982-04-26 21:00:00   118.94   119.33   118.25    119.26   118.94   119.33
# 1982-04-27 21:00:00   119.07   119.26   117.73    118.00   119.07   119.26
# ...                      ...      ...      ...       ...      ...      ...
# 2024-06-25 21:00:00  5481.75  5499.05  5463.59   5480.89  5482.35  5499.65
# 2024-06-26 21:00:00  5480.89  5502.79  5463.73   5497.35  5481.29  5503.29
# 2024-06-27 21:00:00  5497.35  5532.83  5458.81   5481.51  5497.75  5533.33
# 2024-06-30 21:00:00  5481.51  5491.61  5455.15   5482.60  5482.11  5492.21
# 2024-07-01 21:00:00  5482.60  5508.54  5453.98   5506.52  5483.20  5509.04
#
# ...

# %%
df=mfih.column_mfi_str_in_dataframe_to_id(df,t)

# %%
df
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 1982-04-21 22:00:00   115.48   116.58   114.44    115.72   115.48   116.58
# 1982-04-22 22:00:00   115.72   117.25   115.72    117.19   115.72   117.25
# 1982-04-23 22:00:00   118.02   118.64   117.19    118.64   118.02   118.64
# 1982-04-26 21:00:00   118.94   119.33   118.25    119.26   118.94   119.33
# 1982-04-27 21:00:00   119.07   119.26   117.73    118.00   119.07   119.26
# ...                      ...      ...      ...       ...      ...      ...
# 2024-06-25 21:00:00  5481.75  5499.05  5463.59   5480.89  5482.35  5499.65
# 2024-06-26 21:00:00  5480.89  5502.79  5463.73   5497.35  5481.29  5503.29
# 2024-06-27 21:00:00  5497.35  5532.83  5458.81   5481.51  5497.75  5533.33
# 2024-06-30 21:00:00  5481.51  5491.61  5455.15   5482.60  5482.11  5492.21
# 2024-07-01 21:00:00  5482.60  5508.54  5453.98   5506.52  5483.20  5509.04
#
# ...
