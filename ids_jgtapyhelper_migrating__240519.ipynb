#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2022-10-03 21:00:00  3682.96  3796.43  3674.16   3791.17  3683.36  3797.03
# 2022-10-04 21:00:00  3791.17  3806.85  3721.58   3782.65  3791.77  3807.35
#
#                       AskLow  AskClose  Volume     Open     High      Low  \
# Date
# 2022-10-03 21:00:00  3674.76   3791.77  172013  3683.16  3796.73  3674.46
# 2022-10-04 21:00:00  3722.08   3783.05  162267  3791.47  3807.10  3721.83
#
#                        Close    Median
# Date
# 2022-10-03 21:00:00  3791.47  3735.595
# 2022-10-04 21:00:00  3782.85  3764.465

# %%
dfsrc.tail(2)
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2024-06-12 21:00:00  5433.32  5447.68  5403.46   5431.18  5433.72  5448.28
# 2024-06-13 21:00:00  5431.18  5433.57  5426.55   5432.06  5431.78  5434.17
#
#                       AskLow  AskClose  Volume     Open     High      Low  \
# Date
# 2024-06-12 21:00:00  5403.96   5431.78  102582  5433.52  5447.98  5403.71
# 2024-06-13 21:00:00  5427.15   5432.66    2295  5431.48  5433.87  5426.85
#
#                        Close    Median
# Date
# 2024-06-12 21:00:00  5431.48  5425.845
# 2024-06-13 21:00:00  5432.36  5430.360

# %%
#how many rows
dfsrc.shape[0]
# Out:
# 439

# %%
rq = RQ.JGTIDSRequest(i,t)

# %%
rq.talligator_flag=talligator_flag
rq.balligator_flag=balligator_flag

# %%
res_jgtids = ids.tocds(dfsrc2,rq=rq)

# %% [markdown]
# ## BELLOW CONFIRM What is Expected

# %% [markdown]
# * JGTIDS (which is more than just IDS) has 60 columns
# * TAH (jgtapyhelper) has 41 columns, just IDS
#
# #### In summary
#
# * JGTIDS with ids.tocds(...) GENERATES SIGNALS

# %% [markdown]
# ----

# %% [markdown]
# #### TOCDS (JGTIDS) Signal Columns
#
# fdbb
# fdbs
# fdb
# aoaz
# aobz
# zlc
# zlcb
# zlcs
# zcol
# sz
# bz
# acs
# acb
# ss
# sb
# price_peak_above
# price_peak_bellow
# ao_peak_above
# ao_peak_bellow
#
# ----

# %%
res_tah= tah.toids(dfsrc,rq=rq)
# Out:
# IDS::debug len(dfsrc):439
#  ADDING SQUAT PROTO Will be in CDS Module
# IDS::debug len(dfresult):295

# %%
res_tah.tail(2)
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2024-06-12 21:00:00  5433.32  5447.68  5403.46   5431.18  5433.72  5448.28
# 2024-06-13 21:00:00  5431.18  5433.57  5426.55   5432.06  5431.78  5434.17
#
#                       AskLow  AskClose  Volume     Open  ...  fl13  fh21  \
# Date                                                     ...
# 2024-06-12 21:00:00  5403.96   5431.78  102582  5433.52  ...     0     0
# 2024-06-13 21:00:00  5427.15   5432.66    2295  5431.48  ...     0     0
#
#                      fl21  fh34  fl34  fh55  fl55  fh89  fl89         mfi
# Date
# 2024-06-12 21:00:00     0     0     0     0     0     0     0   43.155719
# 2024-06-13 21:00:00     0     0     0     0     0     0     0  305.882353
#
# [2 rows x 41 columns]

# %%
res_tah.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5', 'fh8', 'fl8', 'fh13', 'fl13',
#        'fh21', 'fl21', 'fh34', 'fl34', 'fh55', 'fl55', 'fh89', 'fl89', 'mfi'],
#       dtype='object')

# %%
# Count number of rows in the two datasets
print("Number of rows in res_jgtids: ",len(res_jgtids))
print("Number of rows in res_tah: ",len(res_tah))
# Out:
# Number of rows in res_jgtids:  295
# Number of rows in res_tah:  295

# %%
res_jgtids.tail(2)
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2024-06-12 21:00:00  5433.32  5447.68  5403.46   5431.18  5433.72  5448.28
# 2024-06-13 21:00:00  5431.18  5433.57  5426.55   5432.06  5431.78  5434.17
#
#                       AskLow  AskClose  Volume     Open  ...   sz   bz  acs  \
# Date                                                     ...
# 2024-06-12 21:00:00  5403.96   5431.78  102582  5433.52  ...  0.0  0.0  1.0
# 2024-06-13 21:00:00  5427.15   5432.66    2295  5431.48  ...  0.0  0.0  0.0
#
#                      acb   ss   sb  price_peak_above  price_peak_bellow  \
# Date
# 2024-06-12 21:00:00  0.0  0.0  0.0                 0                  0
# 2024-06-13 21:00:00  0.0  0.0  0.0                 0                  0
#
#                      ao_peak_above  ao_peak_bellow
# Date
# 2024-06-12 21:00:00              0               0
# 2024-06-13 21:00:00              0               0
#
# [2 rows x 60 columns]

# %%
res_jgtids.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5', 'fh8', 'fl8', 'fh13', 'fl13',
#        'fh21', 'fl21', 'fh34', 'fl34', 'fh55', 'fl55', 'fh89', 'fl89', 'mfi',
#        'fdbb', 'fdbs', 'fdb', 'aoaz', 'aobz', 'zlc', 'zlcb', 'zlcs', 'zcol',
#        'sz', 'bz', 'acs', 'acb', 'ss', 'sb', 'price_peak_above',
#        'price_peak_bellow', 'ao_peak_above', 'ao_peak_bellow'],
#       dtype='object')

# %%
res_tah.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5', 'fh8', 'fl8', 'fh13', 'fl13',
#        'fh21', 'fl21', 'fh34', 'fl34', 'fh55', 'fl55', 'fh89', 'fl89', 'mfi'],
#       dtype='object')

# %%
# Compare the two datasets from ids.tocds(... ) and tah.toids(...)
## List of columns that are different
for c in res_jgtids.columns:
    if c not in res_tah.columns:
        print(c)
# Out:
# fdbb
# fdbs
# fdb
# aoaz
# aobz
# zlc
# zlcb
# zlcs
# zcol
# sz
# bz
# acs
# acb
# ss
# sb
# price_peak_above
# price_peak_bellow
# ao_peak_above
# ao_peak_bellow
