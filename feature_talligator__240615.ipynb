# %%
from jgtpy import JGTIDS as ids,JGTIDSRequest as RQ
from jgtpy import jgtapyhelper as tah
from jgtpy import JGTPDSP as pds


i="SPX500";t="D1"

quote_count=-1

talligator_flag=True
balligator_flag=True
# if talligator_flag:
#   quote_count=1200

# %%
  
# dfsrc = pds.getPH(i,t,use_fresh=False,quote_count=quote_count)
use_fresh = False
use_full=False
refresh_data=False

if refresh_data:
  dfsrc = pds.getPH(i,t,use_fresh=use_fresh,talligator_flag=talligator_flag,use_full=use_full)
else:
  povfn=pds.get_pov_local_data_filename(i,t,use_full=use_full)
  dfsrc=pds.read_ohlc_df_from_file(povfn)

# %%
dfsrc2=dfsrc.copy()
dfsrc
# Out:
#                      BidOpen  BidHigh   BidLow  BidClose  AskOpen  AskHigh  \
# Date
# 2019-10-13 21:00:00  2970.90  2983.38  2954.90   2967.16  2971.28  2983.90
# 2019-10-14 21:00:00  2967.16  3004.08  2967.16   2997.34  2968.04  3004.50
# 2019-10-15 21:00:00  2997.34  2998.54  2985.70   2993.06  2997.90  2998.98
# 2019-10-16 21:00:00  2993.06  3008.92  2986.36   2998.58  2993.56  3009.30
# 2019-10-17 21:00:00  2998.58  3002.00  2976.10   2988.90  2999.42  3002.70
# ...                      ...      ...      ...       ...      ...      ...
# 2024-06-10 21:00:00  5362.98  5380.13  5328.43   5377.98  5363.38  5380.73
# 2024-06-11 21:00:00  5377.98  5449.28  5374.73   5433.32  5378.38  5449.78
# 2024-06-12 21:00:00  5433.32  5447.68  5403.46   5431.18  5433.72  5448.28
# 2024-06-13 21:00:00  5431.18  5437.32  5392.30   5429.92  5431.78  5437.92
# 2024-06-16 21:00:00  5429.92  5435.82  5428.30   5432.32  5430.32  5436.42
#
#                       AskLow  AskClose  Volume     Open     High      Low  \
# Date
# 2019-10-13 21:00:00  2955.46   2968.04  344653  2971.09  2983.64  2955.18
# 2019-10-14 21:00:00  2968.04   2997.90  323573  2967.60  3004.29  2967.60
# 2019-10-15 21:00:00  2986.32   2993.56  369466  2997.62  2998.76  2986.01
# 2019-10-16 21:00:00  2986.78   2999.42  385109  2993.31  3009.11  2986.57
# 2019-10-17 21:00:00  2976.62   2989.54  368110  2999.00  3002.35  2976.36
# ...                      ...       ...     ...      ...      ...      ...
# 2024-06-10 21:00:00  5328.93   5378.38   83933  5363.18  5380.43  5328.68
# 2024-06-11 21:00:00  5375.33   5433.72  135387  5378.18  5449.53  5375.03
# 2024-06-12 21:00:00  5403.96   5431.78  102589  5433.52  5447.98  5403.71
# 2024-06-13 21:00:00  5392.90   5430.32  126577  5431.48  5437.62  5392.60
# 2024-06-16 21:00:00  5428.90   5432.92    6686  5430.12  5436.12  5428.60
#
#                        Close    Median
# Date
# 2019-10-13 21:00:00  2967.60  2969.410
# 2019-10-14 21:00:00  2997.62  2985.945
# 2019-10-15 21:00:00  2993.31  2992.385
# 2019-10-16 21:00:00  2999.00  2997.840
# 2019-10-17 21:00:00  2989.22  2989.355
# ...                      ...       ...
# 2024-06-10 21:00:00  5378.18  5354.555
# 2024-06-11 21:00:00  5433.52  5412.280
# 2024-06-12 21:00:00  5431.48  5425.845
# 2024-06-13 21:00:00  5430.12  5415.110
# 2024-06-16 21:00:00  5432.62  5432.360
#
# [1210 rows x 14 columns]

# %%
rq = RQ.JGTIDSRequest(i,t)
rq.talligator_flag=talligator_flag
rq.balligator_flag=balligator_flag

# %%
res_tah= tah.toids(dfsrc,rq=rq)
# Out:
#  ADDING SQUAT PROTO Will be in CDS Module

# %%
res_tah.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'tjaw', 'tteeth', 'tlips', 'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5',
#        'fh8', 'fl8', 'fh13', 'fl13', 'fh21', 'fl21', 'fh34', 'fl34', 'fh55',
#        'fl55', 'fh89', 'fl89', 'mfi'],
#       dtype='object')

# %%
use_IDS_v2_from_jgtapyhelper = True
res_jgtids = ids.tocds(dfsrc2,rq=rq,use_v2=use_IDS_v2_from_jgtapyhelper)
# Out:
#  ADDING SQUAT PROTO Will be in CDS Module

# %%
res_jgtids.columns
# Out:
# Index(['BidOpen', 'BidHigh', 'BidLow', 'BidClose', 'AskOpen', 'AskHigh',
#        'AskLow', 'AskClose', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Median', 'ao', 'ac', 'jaw', 'teeth', 'lips', 'bjaw', 'bteeth', 'blips',
#        'tjaw', 'tteeth', 'tlips', 'fh', 'fl', 'fh3', 'fl3', 'fh5', 'fl5',
#        'fh8', 'fl8', 'fh13', 'fl13', 'fh21', 'fl21', 'fh34', 'fl34', 'fh55',
#        'fl55', 'fh89', 'fl89', 'mfi', 'fdbb', 'fdbs', 'fdb', 'aoaz', 'aobz',
#        'zlc', 'zlcb', 'zlcs', 'zcol', 'sz', 'bz', 'acs', 'acb', 'ss', 'sb',
#        'price_peak_above', 'price_peak_bellow', 'ao_peak_above',
#        'ao_peak_bellow'],
#       dtype='object')

# %%
# Count number of rows in the two datasets
print("Number of rows in res_jgtids: ",len(res_jgtids))
print("Number of rows in res_tah: ",len(res_tah))
# Out:
# Number of rows in res_jgtids:  600
# Number of rows in res_tah:  600

# %%
res_tah.to_csv("res_tah.csv")
