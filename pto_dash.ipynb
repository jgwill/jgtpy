# %%
import plotly.graph_objects as go
import plotly.subplots as sp

def convert_mpf_plot_to_plotly_dash(fig, axes):
    """
    Converts an mplfinance plot to a plotly dash plot.

    Args:
        fig (matplotlib.figure.Figure): The mplfinance figure object.
        axes (matplotlib.axes.Axes): The mplfinance axes object.

    Returns:
        plotly.graph_objects.Figure: The plotly dash figure object.
    """

    # Get the data from the mplfinance plot
    data = [go.Scatter(x=line.get_xdata(), y=line.get_ydata()) for ax in axes.values() for line in ax.lines]

    # Create a plotly dash figure
    fig = sp.make_subplots(rows=len(axes), cols=1, shared_xaxes=True, subplot_titles=axes.keys())

    # Add the data to the plotly dash figure
    for i, trace in enumerate(data):
        fig.add_trace(trace, row=i+1, col=1)

    # Update the layout of the plotly dash figure
    fig.update_layout(height=fig.canvas.get_window_height(), width=fig.canvas.get_window_width())

    return fig

# %%
# Example usage
import matplotlib.pyplot as plt
import mplfinance as mpf

import pandas as pd
data = pd.read_csv("./data/cds/EUR-USD_H4.csv", index_col=0, parse_dates=True)

# %%
# Create an mplfinance plot
fig, axes = plt.subplots(2,1, figsize=(10,5))
mpf.plot(data, ax=axes[0], type='candle', style='yahoo')
mpf.plot(data, ax=axes[1], type='line', style='yahoo', mav=(5,20))
# Out:
# c:\usr\local\anaconda\envs\jgtpy310\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
# Convert the mplfinance plot to a plotly dash plot
pfig = convert_mpf_plot_to_plotly_dash(fig, axes)

# Display the plotly dash plot
pfig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Convert the mplfinance plot to a plotly dash plot
# ----> 2 pfig = convert_mpf_plot_to_plotly_dash(fig, axes)
#       4 # Display the plotly dash plot
#       5 pfig.show()
#
# Cell In[1], line 17, in convert_mpf_plot_to_plotly_dash(fig, axes)
#       5 """
#       6 Converts an mplfinance plot to a plotly dash plot.
#       7
#    (...)
#      13     plotly.graph_objects.Figure: The plotly dash figure object.
#      14 """
#      16 # Get the data from the mplfinance plot
# ---> 17 data = fig.data
#      19 # Create a plotly dash figure
#      20 fig = sp.make_subplots(rows=len(axes), cols=1, shared_xaxes=True, subplot_titles=axes.keys())
#
# AttributeError: 'Figure' object has no attribute 'data'

# %%
# Convert the mplfinance plot to a plotly dash plot
pfig = convert_mpf_plot_to_plotly_dash(fig, axes)

# Display the plotly dash plot
pfig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Convert the mplfinance plot to a plotly dash plot
# ----> 2 pfig = convert_mpf_plot_to_plotly_dash(fig, axes)
#       4 # Display the plotly dash plot
#       5 pfig.show()
#
# Cell In[1], line 17, in convert_mpf_plot_to_plotly_dash(fig, axes)
#       5 """
#       6 Converts an mplfinance plot to a plotly dash plot.
#       7
#    (...)
#      13     plotly.graph_objects.Figure: The plotly dash figure object.
#      14 """
#      16 # Get the data from the mplfinance plot
# ---> 17 data = fig.data
#      19 # Create a plotly dash figure
#      20 fig = sp.make_subplots(rows=len(axes), cols=1, shared_xaxes=True, subplot_titles=axes.keys())
#
# AttributeError: 'Figure' object has no attribute 'data'
